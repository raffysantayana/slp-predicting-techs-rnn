# %%
import pandas as pd
import slippi as slp

# %%
df = pd.read_csv('../data/fp9.csv')

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df.head()
# Out:
#            game_id                       date  duration             platform  \
# 0  20190406T182021  2019-04-06 18:20:21+00:00     11653  Platform.NINTENDONT
# 1  20190406T054329  2019-04-06 05:43:29+00:00      1435  Platform.NINTENDONT
# 2  20190406T113710  2019-04-06 11:37:10+00:00      7577  Platform.NINTENDONT
# 3  20190406T060932  2019-04-06 06:09:32+00:00      9589  Platform.NINTENDONT
# 4  20190406T063208  2019-04-06 06:32:08+00:00     10043  Platform.NINTENDONT
#
#    p1_char  p2_char  p3_char  p4_char  stage  is_teams  is_pal
# 0     14.0      NaN      NaN      9.0     32     False   False
# 1      NaN     20.0     18.0      NaN     31     False   False
# 2     22.0      2.0      2.0      2.0      3      True   False
# 3     20.0      NaN      NaN      7.0     28     False   False
# 4     14.0      NaN      NaN      9.0      8     False   False

# %%
mask_no_teams = (df['is_teams'] == False)

# %%
asdf = df.loc[mask_no_teams]
asdf
# Out:
#               game_id                       date  duration  \
# 0     20190406T182021  2019-04-06 18:20:21+00:00     11653
# 1     20190406T054329  2019-04-06 05:43:29+00:00      1435
# 3     20190406T060932  2019-04-06 06:09:32+00:00      9589
# 4     20190406T063208  2019-04-06 06:32:08+00:00     10043
# 5     20190406T132735  2019-04-06 13:27:35+00:00     12883
# ...               ...                        ...       ...
# 1141  20190406T060724  2019-04-06 06:07:24+00:00      4462
# 1142  20190406T175301  2019-04-06 17:53:01+00:00     12113
# 1143  20190406T152033  2019-04-06 15:20:33+00:00     11529
# 1144  20190406T111644  2019-04-06 11:16:44+00:00      8038
# 1145  20190406T115436  2019-04-06 11:54:36+00:00     10684
#
#                  platform  p1_char  p2_char  p3_char  p4_char  stage  \
# 0     Platform.NINTENDONT     14.0      NaN      NaN      9.0     32
# 1     Platform.NINTENDONT      NaN     20.0     18.0      NaN     31
# ...

# %%
df['duration']
# Out:
# 0       11653
# 1        1435
# 2        7577
# 3        9589
# 4       10043
#         ...
# 1141     4462
# 1142    12113
# 1143    11529
# 1144     8038
# 1145    10684
# Name: duration, Length: 1146, dtype: int64

# %%
7

# %%
for duration in df['duration']:
    print(duration)
# Out:
# 11653
# 1435
# 7577
# 9589
# 10043
# 12883
# 5168
# 10627
# 9608
# 11072
# 7424
# 5610
# 7016
# 12301
# 8593
# 11689
# 7497
# 8679
# 10629
# 3031
# 5384
# 10377
# 19524
# 9850
# 6112
# 10414
# 11005
# 8011
# 1586
# 9960
# 9844
# 14445
# 125
# 7941
# 10232
# 10299
# 12191
# 11070
# 8153
# 13589
# 11931
# 11100
# 15950
# 7385
# 10019
# 13889
# 11908
# 3270
# 141
# 9441
# 12908
# 8175
# 1890
# 13812
# 12614
# 3168
# 12592
# 12352
# 1095
# 6512
# 6420
# 7080
# 11063
# 7906
# 9812
# 10314
# 17276
# 14361
# 12604
# 9872
# 11522
# 10255
# 6060
# 6926
# 8056
# 9048
# 15492
# 10484
# 8466
# 10181
# 11341
# 18517
# 9379
# 13448
# 8718
# 8161
# 9842
# 10079
# 10178
# 8711
# 13759
# 8223
# 14510
# 5430
# 15009
# 11320
# 1128
# 10710
# 9490
# 11637
# 9702
# 9743
# 10903
# 5410
# 2782
# 9022
# 14180
# 9892
# 5844
# 11188
# 1103
# 12721
# 9930
# 16620
# 10389
# 8985
# 12781
# 14849
# 6002
# 1768
# 13876
# 888
# 11408
# 9448
# 10436
# 10950
# 15234
# 11112
# 7439
# 6946
# 2510
# 14351
# 9189
# ...
