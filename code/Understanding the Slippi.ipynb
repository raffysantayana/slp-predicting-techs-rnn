# %% [markdown]
# Import slippi

# %%
import pandas as pd
import slippi as sl

# %% [markdown]
# Reading game data from `slippi` file.

# %%
game = sl.Game('/Users/raffy/Downloads/BTSSmash-Game_20190922T193150.slp')

# %%
type(game)
# Out:
# slippi.game.Game

# %% [markdown]
# # Slippi.event module

# %%
game.start.is_teams
# Out:
# False

# %%
game.start.players
# Out:
# (Player(character=CSSCharacter.JIGGLYPUFF, costume=3, stocks=4, tag=, team=None, type=Type.HUMAN, ucf=UCF(dash_back=DashBack.UCF, shield_drop=ShieldDrop.UCF)),
#  Player(character=CSSCharacter.FALCO, costume=3, stocks=4, tag=, team=None, type=Type.HUMAN, ucf=UCF(dash_back=DashBack.UCF, shield_drop=ShieldDrop.UCF)),
#  None,
#  None)

# %%
game.start.random_seed
# Out:
# 2937919085

# %%
game.start.stage
# Out:
# Stage.POKEMON_STADIUM

# %%
game.start.slippi
# Out:
# Slippi(version=2.0.1)

# %%
game.start.is_frozen_ps
# Out:
# False

# %%
game.start.is_pal
# Out:
# False

# %%
# Tuple of players
game.start.players
# Out:
# (Player(character=CSSCharacter.JIGGLYPUFF, costume=3, stocks=4, tag=, team=None, type=Type.HUMAN, ucf=UCF(dash_back=DashBack.UCF, shield_drop=ShieldDrop.UCF)),
#  Player(character=CSSCharacter.FALCO, costume=3, stocks=4, tag=, team=None, type=Type.HUMAN, ucf=UCF(dash_back=DashBack.UCF, shield_drop=ShieldDrop.UCF)),
#  None,
#  None)

# %%
game.start.players[0].character
# Out:
# CSSCharacter.JIGGLYPUFF

# %%
game.start.players[0].costume
# Out:
# 3

# %%
game.start.players[0].stocks
# Out:
# 4

# %%
game.start.players[0].tag
# Out:
# ''

# %%
game.start.players[0].team

# %%
game.start.players[0].type
# Out:
# Type.HUMAN

# %%
game.start.players[0].ucf
# Out:
# UCF(dash_back=DashBack.UCF, shield_drop=ShieldDrop.UCF)

# %% [markdown]
# ## Attributes of `Game` Object

# %% [markdown]
# ### game.metadata
# Miscellaneous data relevant to the game but not directly provided by Melee.

# %%
game.metadata
# Out:
# Metadata(date=2019-09-22 19:31:50+00:00, duration=8184, platform=Platform.NETWORK, players=(Player(characters={InGameCharacter.JIGGLYPUFF: 8184}), Player(characters={InGameCharacter.FALCO: 8184}), None, None))

# %% [markdown]
# #### game.metadata.date
# Game start date & time

# %%
game.metadata.date
# Out:
# datetime.datetime(2019, 9, 22, 19, 31, 50, tzinfo=datetime.timezone.utc)

# %% [markdown]
# #### game.metadata.duration
# Duration of game, in frames

# %%
game.metadata.duration
# Out:
# 8184

# %% [markdown]
# #### game.metadata.platform
# Platform the game was played on (console/dolphin)

# %%
game.metadata.platform
# Out:
# Platform.NETWORK

# %%
sl.Game.Metadata.Platform.CONSOLE
# Out:
# Platform.CONSOLE

# %%
sl.Game.Metadata.Platform.NETWORK
# Out:
# Platform.NETWORK

# %% [markdown]
# #### game.metadata.players
# Player metadata by port (port 1 is at index 0; empty ports will contain None)

# %%
game.metadata.players
# Out:
# (Player(characters={InGameCharacter.JIGGLYPUFF: 8184}),
#  Player(characters={InGameCharacter.FALCO: 8184}),
#  None,
#  None)

# %% [markdown]
# ### slippi.util

# %% [markdown]
# #### slippi.util.unpack

# %%
sl.util.unpack
# Out:
# <function slippi.util.unpack(fmt, stream)>

# %% [markdown]
# ### game.frames
# Returns a list of `Frame` objects. One `Frame` per frame in `Game`.

# %%
game.frames
# Out:
# [Frame(index=-123, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.DEAD, ground=None, hit_stun=4, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.00), random_seed=2879818179, raw_analog_x=(251,), state=ActionState.ENTRY, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.DEAD, ground=None, hit_stun=9, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=2879818179, raw_analog_x=(0,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.00))))), None, None)),
#  Frame(index=-122, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.DEAD, ground=None, hit_stun=3, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.00), random_seed=3608399226, raw_analog_x=(255,), state=ActionState.ENTRY, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.DEAD, ground=None, hit_stun=8, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=3608399226, raw_analog_x=(0,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.00))))), None, None)),
#  Frame(index=-121, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.DEAD, ground=None, hit_stun=2, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.00), random_seed=636329557, raw_analog_x=(0,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.DEAD, ground=None, hit_stun=7, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=636329557, raw_analog_x=(0,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.00))))), None, None)),
#  Frame(index=-120, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.DEAD, ground=None, hit_stun=1, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.00), random_seed=2271958980, raw_analog_x=(255,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.DEAD, ground=None, hit_stun=6, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=2271958980, raw_analog_x=(0,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.00))))), None, None)),
#  Frame(index=-119, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.DEAD, ground=None, hit_stun=0, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.00), random_seed=4102072183, raw_analog_x=(255,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.DEAD, ground=None, hit_stun=5, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=4102072183, raw_analog_x=(0,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.00))))), None, None)),
#  Frame(index=-118, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=29, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.04), shield=60.00, state=ActionState.ENTRY_START, state_age=0.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.00), random_seed=1166361694, raw_analog_x=(250,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.DEAD, ground=None, hit_stun=4, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=1166361694, raw_analog_x=(0,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.00))))), None, None)),
#  Frame(index=-117, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=28, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.08), shield=60.00, state=ActionState.ENTRY_START, state_age=1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.04), random_seed=420448187, raw_analog_x=(250,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.DEAD, ground=None, hit_stun=3, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=420448187, raw_analog_x=(0,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.05))))), None, None)),
#  Frame(index=-116, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=27, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.13), shield=60.00, state=ActionState.ENTRY_START, state_age=2.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.08), random_seed=2429078244, raw_analog_x=(248,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.DEAD, ground=None, hit_stun=2, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=2429078244, raw_analog_x=(0,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.05))))), None, None)),
#  Frame(index=-115, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=26, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.17), shield=60.00, state=ActionState.ENTRY_START, state_age=3.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.13), random_seed=1090280892, raw_analog_x=(238,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.DEAD, ground=None, hit_stun=1, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=1090280892, raw_analog_x=(0,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.05))))), None, None)),
#  Frame(index=-114, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=25, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.21), shield=60.00, state=ActionState.ENTRY_START, state_age=4.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|JOYSTICK_LEFT|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.38, 0.00), position=(-40.00, 32.17), random_seed=263213064, raw_analog_x=(226,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.DEAD, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.00), shield=60.00, state=ActionState.ENTRY, state_age=-1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=263213064, raw_analog_x=(1,), state=ActionState.ENTRY, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.05))))), None, None)),
#  Frame(index=-113, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=24, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.25), shield=60.00, state=ActionState.ENTRY_START, state_age=5.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|JOYSTICK_LEFT|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.32, 0.29), position=(-40.00, 32.21), random_seed=51224868, raw_analog_x=(230,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=29, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.04), shield=60.00, state=ActionState.ENTRY_START, state_age=0.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.00), random_seed=51224868, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.05))))), None, None)),
#  Frame(index=-112, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=23, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.30), shield=60.00, state=ActionState.ENTRY_START, state_age=6.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.25), random_seed=2357401021, raw_analog_x=(238,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=28, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.08), shield=60.00, state=ActionState.ENTRY_START, state_age=1.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.04), random_seed=2357401021, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.05))))), None, None)),
#  Frame(index=-111, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=22, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.34), shield=60.00, state=ActionState.ENTRY_START, state_age=7.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.30), random_seed=3737500292, raw_analog_x=(2,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=27, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.13), shield=60.00, state=ActionState.ENTRY_START, state_age=2.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.08), random_seed=3737500292, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.05))))), None, None)),
#  Frame(index=-110, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=21, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.38), shield=60.00, state=ActionState.ENTRY_START, state_age=8.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.34), random_seed=295447381, raw_analog_x=(253,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=26, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.17), shield=60.00, state=ActionState.ENTRY_START, state_age=3.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.13), random_seed=295447381, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.05))))), None, None)),
#  Frame(index=-109, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=20, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.42), shield=60.00, state=ActionState.ENTRY_START, state_age=9.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-40.00, 32.38), random_seed=2381649596, raw_analog_x=(240,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=25, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.21), shield=60.00, state=ActionState.ENTRY_START, state_age=4.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.17), random_seed=2381649596, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.44, physical=Physical(l=0.44, r=0.04))))), None, None)),
#  Frame(index=-108, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=19, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.47), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|JOYSTICK_LEFT|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.77, 0.62), position=(-40.00, 32.42), random_seed=429966013, raw_analog_x=(174,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=24, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.25), shield=60.00, state=ActionState.ENTRY_START, state_age=5.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.21), random_seed=429966013, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=0.04))))), None, None)),
#  Frame(index=-107, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=18, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.51), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|JOYSTICK_LEFT|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.71, 0.69), position=(-40.00, 32.47), random_seed=1612657244, raw_analog_x=(178,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=23, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.30), shield=60.00, state=ActionState.ENTRY_START, state_age=6.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|L, physical=Physical.L), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.25), random_seed=1612657244, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=0.04))))), None, None)),
#  Frame(index=-106, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=17, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.55), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_UP, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.61, 0.77), position=(-40.00, 32.51), random_seed=2095856662, raw_analog_x=(190,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=22, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.34), shield=60.00, state=ActionState.ENTRY_START, state_age=7.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|L, physical=Physical.L), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.30), random_seed=2095856662, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=0.04))))), None, None)),
#  Frame(index=-105, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=16, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.59), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_UP, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.51, 0.85), position=(-40.00, 32.55), random_seed=2432711964, raw_analog_x=(208,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=21, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.38), shield=60.00, state=ActionState.ENTRY_START, state_age=8.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|L, physical=Physical.L), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.34), random_seed=2432711964, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=0.04))))), None, None)),
#  Frame(index=-104, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=15, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.64), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_RIGHT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.99, 0.00), position=(-40.00, 32.59), random_seed=3351264470, raw_analog_x=(92,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=20, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.42), shield=60.00, state=ActionState.ENTRY_START, state_age=9.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|L, physical=Physical.L), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.38), random_seed=3351264470, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=0.04))))), None, None)),
#  Frame(index=-103, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=14, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.68), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_RIGHT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.96, 0.00), position=(-40.00, 32.64), random_seed=3072177462, raw_analog_x=(102,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=19, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.47), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|L, physical=Physical.L), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.42), random_seed=3072177462, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=0.04))))), None, None)),
#  Frame(index=-102, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=13, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.72), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_RIGHT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.90, -0.41), position=(-40.00, 32.68), random_seed=1691862404, raw_analog_x=(92,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=18, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.51), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|L, physical=Physical.L), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.47), random_seed=1691862404, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=0.04))))), None, None)),
#  Frame(index=-101, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=12, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.76), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.99, 0.00), position=(-40.00, 32.72), random_seed=1231238888, raw_analog_x=(153,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=17, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.55), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|L, physical=Physical.L), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.51), random_seed=1231238888, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=0.04))))), None, None)),
#  Frame(index=-100, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=11, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.81), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.99, 0.00), position=(-40.00, 32.76), random_seed=1511874120, raw_analog_x=(154,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=16, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.59), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|L, physical=Physical.L), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.55), random_seed=1511874120, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=0.04))))), None, None)),
#  Frame(index=-99, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=10, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.85), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.95, 0.30), position=(-40.00, 32.81), random_seed=801387165, raw_analog_x=(163,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=15, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.64), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.59), random_seed=801387165, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=0.53))))), None, None)),
#  Frame(index=-98, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=9, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.89), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.95, 0.00), position=(-40.00, 32.85), random_seed=787541767, raw_analog_x=(180,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=14, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.68), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|R, physical=Physical.R), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.64), random_seed=787541767, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=1.00, r=1.00))))), None, None)),
#  Frame(index=-97, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=8, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.93), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_RIGHT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.84, -0.54), position=(-40.00, 32.89), random_seed=1893646897, raw_analog_x=(89,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=13, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.72), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|R, physical=Physical.R), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.68), random_seed=1893646897, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=0.79, r=1.00))))), None, None)),
#  Frame(index=-96, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=7, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 32.98), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_RIGHT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.77, -0.61), position=(-40.00, 32.93), random_seed=1602063383, raw_analog_x=(88,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=12, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.76), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|R, physical=Physical.R), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.72), random_seed=1602063383, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=0.09, r=1.00))))), None, None)),
#  Frame(index=-95, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=6, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 33.02), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|JOYSTICK_DOWN|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.41, -0.81), position=(-40.00, 32.98), random_seed=3378453060, raw_analog_x=(33,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=11, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.81), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|R, physical=Physical.R), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.76), random_seed=3378453060, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=0.09, r=1.00))))), None, None)),
#  Frame(index=-94, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=5, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 33.06), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|JOYSTICK_LEFT|A|Z, physical=Physical.Z), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.99, 0.00), position=(-40.00, 33.02), random_seed=128540284, raw_analog_x=(155,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.35, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=10, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.85), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|A|R, physical=Physical.A|R), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.81), random_seed=128540284, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=0.08, r=1.00))))), None, None)),
#  Frame(index=-93, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=4, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 33.10), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.90, 0.41), position=(-40.00, 33.06), random_seed=643228237, raw_analog_x=(163,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.00))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=9, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.89), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|A|R, physical=Physical.A|R), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.85), random_seed=643228237, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=0.08, r=1.00))))), None, None)),
#  Frame(index=-92, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=3, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 33.15), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(-0.90, 0.41), position=(-40.00, 33.10), random_seed=768685099, raw_analog_x=(175,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.04))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=8, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.93), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|R, physical=Physical.R), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.89), random_seed=768685099, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=0.08, r=1.00))))), None, None)),
#  Frame(index=-91, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.0, ground=None, hit_stun=2, jumps=5, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(-40.00, 33.19), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_RIGHT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.88, -0.46), position=(-40.00, 33.15), random_seed=3525368497, raw_analog_x=(91,), state=ActionState.ENTRY_START, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.11))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=0, damage=0.00, direction=Direction.LEFT, flags=StateFlags.0, ground=None, hit_stun=7, jumps=1, l_cancel=None, last_attack_landed=None, last_hit_by=None, position=(40.00, 32.98), shield=60.00, state=ActionState.ENTRY_START, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.TRIGGER_ANALOG|B|R, physical=Physical.B|R), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.LEFT, joystick=(0.00, 0.00), position=(40.00, 32.93), random_seed=3525368497, raw_analog_x=(1,), state=ActionState.ENTRY_START, triggers=Triggers(logical=1.00, physical=Physical(l=0.08, r=1.00))))), None, None)),
# ...
#  Frame(index=866, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(58.05, 15.26), shield=60.00, state=ActionState.WAIT_1, state_age=4.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.77, 0.62), position=(57.32, 13.47), random_seed=3071240545, raw_analog_x=(172,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.03, r=0.04))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-44.59, 8.85), shield=60.00, state=ActionState.WAIT_4, state_age=3.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.B, physical=Physical.B), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-46.19, 7.80), random_seed=3071240545, raw_analog_x=(0,), state=ActionState.WAIT_4, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  Frame(index=867, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(58.68, 16.97), shield=60.00, state=ActionState.WAIT_1, state_age=5.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.85, 0.51), position=(58.05, 15.26), random_seed=2738547226, raw_analog_x=(166,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.03, r=0.04))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-43.01, 9.73), shield=60.00, state=ActionState.WAIT_4, state_age=4.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.B, physical=Physical.B), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-44.59, 8.85), random_seed=2738547226, raw_analog_x=(0,), state=ActionState.WAIT_4, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  Frame(index=868, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(59.20, 18.59), shield=60.00, state=ActionState.WAIT_1, state_age=6.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.96, 0.00), position=(58.68, 16.97), random_seed=2212014440, raw_analog_x=(155,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.03, r=0.05))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-41.45, 10.44), shield=60.00, state=ActionState.WAIT_ITEM, state_age=0.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.B, physical=Physical.B), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-43.01, 9.73), random_seed=2212014440, raw_analog_x=(0,), state=ActionState.WAIT_ITEM, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  Frame(index=869, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(59.60, 20.12), shield=60.00, state=ActionState.WAIT_1, state_age=7.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.99, 0.00), position=(59.20, 18.59), random_seed=1556250246, raw_analog_x=(150,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.03, r=0.05))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-39.91, 10.98), shield=60.00, state=ActionState.WAIT_ITEM, state_age=1.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.B, physical=Physical.B), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-41.45, 10.44), random_seed=1556250246, raw_analog_x=(0,), state=ActionState.WAIT_ITEM, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  Frame(index=870, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(59.88, 21.56), shield=60.00, state=ActionState.WAIT_1, state_age=8.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.99, 0.00), position=(59.60, 20.12), random_seed=3759343914, raw_analog_x=(150,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.03, r=0.05))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-38.39, 11.35), shield=60.00, state=ActionState.WAIT_ITEM, state_age=2.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.B, physical=Physical.B), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-39.91, 10.98), random_seed=3759343914, raw_analog_x=(0,), state=ActionState.WAIT_ITEM, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  Frame(index=871, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(60.05, 22.92), shield=60.00, state=ActionState.WAIT_1, state_age=9.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.99, 0.00), position=(59.88, 21.56), random_seed=1161701134, raw_analog_x=(150,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.03, r=0.05))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-36.89, 11.55), shield=60.00, state=ActionState.WAIT_ITEM, state_age=3.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, -0.36), position=(-38.39, 11.35), random_seed=1161701134, raw_analog_x=(0,), state=ActionState.WAIT_ITEM, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  Frame(index=872, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(60.10, 24.18), shield=60.00, state=ActionState.WAIT_1, state_age=10.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.99, 0.00), position=(60.05, 22.92), random_seed=1532353586, raw_analog_x=(150,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.03, r=0.05))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-35.41, 11.58), shield=60.00, state=ActionState.WAIT_ITEM, state_age=4.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_DOWN, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.52, -0.84), position=(-36.89, 11.55), random_seed=1532353586, raw_analog_x=(52,), state=ActionState.WAIT_ITEM, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  Frame(index=873, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(60.04, 25.36), shield=60.00, state=ActionState.WAIT_1, state_age=11.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.99, 0.00), position=(60.10, 24.18), random_seed=1145924758, raw_analog_x=(149,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.03, r=0.04))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-33.95, 11.44), shield=60.00, state=ActionState.WAIT_ITEM, state_age=5.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_DOWN, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.49, -0.86), position=(-35.41, 11.58), random_seed=1145924758, raw_analog_x=(51,), state=ActionState.WAIT_ITEM, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  Frame(index=874, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(59.86, 26.45), shield=60.00, state=ActionState.WAIT_1, state_age=12.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.99, 0.00), position=(60.04, 25.36), random_seed=2136824890, raw_analog_x=(150,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.02, r=0.04))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.FAST_FALL|128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-32.51, 7.94), shield=60.00, state=ActionState.WAIT_ITEM, state_age=6.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_DOWN, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.43, -0.89), position=(-33.95, 11.44), random_seed=2136824890, raw_analog_x=(50,), state=ActionState.WAIT_ITEM, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  Frame(index=875, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(59.56, 27.46), shield=60.00, state=ActionState.WAIT_1, state_age=13.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.99, 0.00), position=(59.86, 26.45), random_seed=1923575582, raw_analog_x=(152,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.01, r=0.03))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.FAST_FALL|128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-31.09, 4.44), shield=60.00, state=ActionState.WAIT_ITEM, state_age=7.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_DOWN, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.46, -0.88), position=(-32.51, 7.94), random_seed=1923575582, raw_analog_x=(45,), state=ActionState.WAIT_ITEM, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  Frame(index=876, ports=(Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.JIGGLYPUFF, combo_count=0, damage=82.60, direction=Direction.LEFT, flags=StateFlags.OFF_SCREEN, ground=None, hit_stun=0, jumps=4, l_cancel=None, last_attack_landed=Attack.DOWN_B, last_hit_by=1, position=(59.15, 28.37), shield=60.00, state=ActionState.WAIT_1, state_age=14.00, stocks=4), pre=Pre(buttons=Buttons(logical=Logical.JOYSTICK_LEFT, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(82.5999984741211,), direction=Direction.LEFT, joystick=(-0.95, -0.29), position=(59.56, 27.46), random_seed=2194528607, raw_analog_x=(157,), state=ActionState.WAIT_1, triggers=Triggers(logical=0.00, physical=Physical(l=0.00, r=0.03))))), Port(follower=None, leader=Data(post=Post(airborne=True, character=InGameCharacter.FALCO, combo_count=1, damage=0.00, direction=Direction.RIGHT, flags=StateFlags.FAST_FALL|128|64, ground=None, hit_stun=0, jumps=1, l_cancel=None, last_attack_landed=Attack.DSMASH, last_hit_by=None, position=(-29.69, 0.94), shield=60.00, state=ActionState.WAIT_ITEM, state_age=8.00, stocks=3), pre=Pre(buttons=Buttons(logical=Logical.NONE, physical=Physical.NONE), cstick=(0.00, 0.00), damage=(0.0,), direction=Direction.RIGHT, joystick=(0.00, 0.00), position=(-31.09, 4.44), random_seed=2194528607, raw_analog_x=(20,), state=ActionState.WAIT_ITEM, triggers=Triggers(logical=0.00, physical=Physical(l=0.04, r=0.02))))), None, None)),
#  ...]

# %%
game.metadata.players[0]
# Out:
# Player(characters={InGameCharacter.JIGGLYPUFF: 8184})

# %%
len(game.frames)
# Out:
# 8184

# %%
game.frames[2].ports[0].leader.post.character
# Out:
# InGameCharacter.JIGGLYPUFF

# %%
game.frames[2].ports[1].follower

# %%
game.start
# Out:
# Start(is_frozen_ps=False, is_pal=False, is_teams=False, players=(Player(character=CSSCharacter.JIGGLYPUFF, costume=3, stocks=4, tag=, team=None, type=Type.HUMAN, ucf=UCF(dash_back=DashBack.UCF, shield_drop=ShieldDrop.UCF)), Player(character=CSSCharacter.FALCO, costume=3, stocks=4, tag=, team=None, type=Type.HUMAN, ucf=UCF(dash_back=DashBack.UCF, shield_drop=ShieldDrop.UCF)), None, None), random_seed=2937919085, slippi=Slippi(version=2.0.1), stage=Stage.POKEMON_STADIUM)

# %%
# Direction char is facing
for frame in game.frames:
    data = frame.ports[0].leader
    print(data.post.direction)
# Out:
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# ...
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.RIGHT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT
# Direction.LEFT

# %%
for frame in game.frames[:300]:
    print(frame.ports[1].leader.post.state)
# Out:
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.WALK_SLOW
# ActionState.WALK_SLOW
# ActionState.WALK_SLOW
# ActionState.WALK_SLOW
# ActionState.TURN
# ActionState.DASH
# ActionState.DASH
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.WALK_SLOW
# ActionState.WALK_SLOW
# ActionState.WALK_SLOW
# ActionState.WALK_SLOW
# ActionState.TURN
# ActionState.DASH
# ActionState.DASH
# ActionState.DASH
# ActionState.DASH
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.WAIT_4
# ActionState.WAIT_4
# ActionState.WAIT_4
# ActionState.WAIT_4
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.WAIT_4
# ActionState.WAIT_4
# ActionState.WAIT_4
# ActionState.WAIT_4
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.WAIT_ITEM
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.TURN
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.LANDING_AIR_N
# ActionState.LANDING_AIR_N
# ActionState.LANDING_AIR_N
# ActionState.LANDING_AIR_N
# ActionState.LANDING_AIR_N
# ActionState.LANDING_AIR_N
# ActionState.LANDING_AIR_N
# ActionState.WAIT
# ActionState.WAIT
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.ATTACK_11
# ActionState.DASH
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.LANDING_AIR_LW
# ActionState.LANDING_AIR_LW
# ActionState.LANDING_AIR_LW
# ActionState.LANDING_AIR_LW
# ActionState.LANDING_AIR_LW
# ActionState.LANDING_AIR_LW
# ActionState.LANDING_AIR_LW
# ActionState.LANDING_AIR_LW
# ActionState.LANDING_AIR_LW
# ActionState.SQUAT
# ActionState.SQUAT
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END
# ActionState.FURA_SLEEP_END

# %%
# Action state of character
for frame in game.frames:
    data = frame.ports[0].leader
    print(data.post.state)
# Out:
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WALK_SLOW
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.WALK_MIDDLE
# ActionState.WALK_FAST
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.TURN
# ActionState.DASH
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.WALK_SLOW
# ActionState.WALK_SLOW
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_OFF
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD
# ActionState.GUARD
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.WAIT_1
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.WAIT
# ActionState.TURN
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.WAIT
# ActionState.WAIT
# ActionState.ATTACK_HI_3
# ActionState.ATTACK_HI_3
# ActionState.ATTACK_HI_3
# ActionState.ATTACK_HI_3
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH_PULL
# ActionState.CATCH_WAIT
# ActionState.CATCH_WAIT
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.WAIT
# ActionState.TURN
# ActionState.TURN
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.WAIT
# ActionState.SQUAT
# ActionState.SQUAT
# ActionState.SQUAT
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.ATTACK_AIR_F
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.WAIT_2
# ActionState.WAIT_2
# ActionState.WAIT_2
# ActionState.WAIT_2
# ActionState.WAIT_2
# ActionState.WAIT_2
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.WAIT_3
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_OFF
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.WAIT
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.DASH
# ActionState.DASH
# ActionState.DASH
# ActionState.DASH
# ActionState.DASH
# ActionState.DASH
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD
# ActionState.GUARD
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.WALK_MIDDLE
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.DAMAGE_FLY_LW
# ActionState.DAMAGE_FLY_LW
# ActionState.DAMAGE_FLY_LW
# ActionState.DAMAGE_FLY_LW
# ActionState.DAMAGE_FLY_LW
# ActionState.DAMAGE_FLY_LW
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.GUARD_ON
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.FALL
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.LANDING_AIR_LW
# ...
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.TURN
# ActionState.DASH
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.WAIT
# ActionState.TURN
# ActionState.DASH
# ActionState.ATTACK_DASH
# ActionState.ATTACK_DASH
# ActionState.ATTACK_DASH
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.TURN
# ActionState.DASH
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.FALL
# ActionState.FALL
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.TURN
# ActionState.TURN
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK

# %%
for frame in game.frames:
    data = frame.ports[0].leader # see also: port.follower (ICs)
    print(data.post.state) # character's post-frame action state
# Out:
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_START
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.ENTRY_END
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WALK_SLOW
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.WALK_MIDDLE
# ActionState.WALK_FAST
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.TURN
# ActionState.DASH
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.WALK_SLOW
# ActionState.WALK_SLOW
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_OFF
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD
# ActionState.GUARD
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.WAIT_1
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.ESCAPE_B
# ActionState.WAIT
# ActionState.TURN
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.LANDING_AIR_HI
# ActionState.WAIT
# ActionState.WAIT
# ActionState.ATTACK_HI_3
# ActionState.ATTACK_HI_3
# ActionState.ATTACK_HI_3
# ActionState.ATTACK_HI_3
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.DAMAGE_HI_2
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH
# ActionState.CATCH_PULL
# ActionState.CATCH_WAIT
# ActionState.CATCH_WAIT
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.THROW_HI
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_ATTACK
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.SLIP_STAND
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.DAMAGE_FLY_HI
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.WAIT
# ActionState.TURN
# ActionState.TURN
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.WAIT
# ActionState.SQUAT
# ActionState.SQUAT
# ActionState.SQUAT
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.PASS
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.ATTACK_AIR_F
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.WAIT_2
# ActionState.WAIT_2
# ActionState.WAIT_2
# ActionState.WAIT_2
# ActionState.WAIT_2
# ActionState.WAIT_2
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.WAIT_3
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_OFF
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.WAIT
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.DASH
# ActionState.DASH
# ActionState.DASH
# ActionState.DASH
# ActionState.DASH
# ActionState.DASH
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_REFLECT
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD
# ActionState.GUARD
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.JUMP_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.WALK_MIDDLE
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.DAMAGE_FLY_LW
# ActionState.DAMAGE_FLY_LW
# ActionState.DAMAGE_FLY_LW
# ActionState.DAMAGE_FLY_LW
# ActionState.DAMAGE_FLY_LW
# ActionState.DAMAGE_FLY_LW
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.DOWN_BOUND_U
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ESCAPE_AIR
# ActionState.ESCAPE_AIR
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.LANDING_FALL_SPECIAL
# ActionState.GUARD_ON
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.ATTACK_AIR_N
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD_ON
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD_SET_OFF
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.GUARD
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.ATTACK_AIR_HI
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DAMAGE_FLY_ROLL
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_BOUND_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.DOWN_FOWARD_D
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.FALL
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.ATTACK_AIR_LW
# ActionState.LANDING_AIR_LW
# ...
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.DAMAGE_AIR_3
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.TURN
# ActionState.DASH
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.ATTACK_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.LANDING_AIR_B
# ActionState.WAIT
# ActionState.TURN
# ActionState.DASH
# ActionState.ATTACK_DASH
# ActionState.ATTACK_DASH
# ActionState.ATTACK_DASH
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.DAMAGE_HI_3
# ActionState.TURN
# ActionState.DASH
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.DAMAGE_AIR_1
# ActionState.FALL
# ActionState.FALL
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.DAMAGE_FLY_TOP
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.FALL
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.LANDING
# ActionState.TURN
# ActionState.TURN
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.WAIT_1
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.ATTACK_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.LANDING_AIR_F
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.TURN
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.WAIT
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.KNEE_BEND
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.JUMP_F
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_CATCH
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_WAIT
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK
# ActionState.CLIFF_CLIMB_QUICK

# %%
slippi.event
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-215ce0ba9039> in <module>
# ----> 1 slippi.event
#
# NameError: name 'slippi' is not defined

# %%
game.start
# Out:
# Start(is_frozen_ps=False, is_pal=False, is_teams=False, players=(Player(character=CSSCharacter.JIGGLYPUFF, costume=3, stocks=4, tag=, team=None, type=Type.HUMAN, ucf=UCF(dash_back=DashBack.UCF, shield_drop=ShieldDrop.UCF)), Player(character=CSSCharacter.FALCO, costume=3, stocks=4, tag=, team=None, type=Type.HUMAN, ucf=UCF(dash_back=DashBack.UCF, shield_drop=ShieldDrop.UCF)), None, None), random_seed=2937919085, slippi=Slippi(version=2.0.1), stage=Stage.POKEMON_STADIUM)

# %%
for frame in game.frames:
    print(frame.state)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-dc4f0ac1c559> in <module>
#       1 for frame in game.frames:
# ----> 2     print(frame.state)
#
# AttributeError: 'Frame' object has no attribute 'state'
