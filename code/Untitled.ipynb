# %%
import os
d = "../data/Fight-Pitt-9/"
for path in os.listdir(d):
    full_path = os.path.join(d, path)
    if os.path.isfile(full_path):
        print(full_path)
# Out:
# ../data/Fight-Pitt-9/Game_20190406T182021.slp
# ../data/Fight-Pitt-9/Game_20190406T054329.slp
# ../data/Fight-Pitt-9/Game_20190406T113710.slp
# ../data/Fight-Pitt-9/Game_20190406T060932.slp
# ../data/Fight-Pitt-9/Game_20190406T063208.slp
# ../data/Fight-Pitt-9/Game_20190406T132735.slp
# ../data/Fight-Pitt-9/Game_20190406T162102.slp
# ../data/Fight-Pitt-9/Game_20190406T193851.slp
# ../data/Fight-Pitt-9/Game_20190406T165651.slp
# ../data/Fight-Pitt-9/Game_20190406T173027.slp
# ../data/Fight-Pitt-9/Game_20190406T091908.slp
# ../data/Fight-Pitt-9/Game_20190406T015639.slp
# ../data/Fight-Pitt-9/Game_20190406T190633.slp
# ../data/Fight-Pitt-9/Game_20190406T104708.slp
# ../data/Fight-Pitt-9/Game_20190406T133629.slp
# ../data/Fight-Pitt-9/Game_20190406T165309.slp
# ../data/Fight-Pitt-9/Game_20190406T173219.slp
# ../data/Fight-Pitt-9/Game_20190406T175640.slp
# ../data/Fight-Pitt-9/Game_20190406T203008.slp
# ../data/Fight-Pitt-9/Game_20190405T110217.slp
# ...

# %%
gang = pd.read_json('/Users/raffy/Downloads/slippi-data.json')

# %%
gang.head()
# Out:
#    gameIdx                                           settings  \
# 0        0  {'isTeams': False, 'isPAL': False, 'stageId': ...
# 1        1  {'isTeams': False, 'isPAL': False, 'stageId': ...
# 2        2  {'isTeams': False, 'isPAL': False, 'stageId': ...
# 3        3  {'isTeams': False, 'isPAL': False, 'stageId': ...
# 4        4  {'isTeams': False, 'isPAL': False, 'stageId': ...
#
#                                                stats  \
# 0  {'stocks': [{'playerIndex': 0, 'opponentIndex'...
# 1  {'stocks': [{'playerIndex': 0, 'opponentIndex'...
# 2  {'stocks': [{'playerIndex': 0, 'opponentIndex'...
# 3  {'stocks': [{'playerIndex': 0, 'opponentIndex'...
# 4  {'stocks': [{'playerIndex': 0, 'opponentIndex'...
#
#                                             metadata
# 0  {'startAt': '2019-03-09T08:13:36', 'lastFrame'...
# 1  {'startAt': '2019-03-09T08:16:03', 'lastFrame'...
# 2  {'startAt': '2019-03-09T09:41:56', 'lastFrame'...
# 3  {'startAt': '2019-03-09T09:44:32', 'lastFrame'...
# ...

# %%
gang.loc[0, 'settings']
# Out:
# {'isTeams': False,
#  'isPAL': False,
#  'stageId': 32,
#  'players': [{'playerIndex': 0,
#    'port': 1,
#    'characterId': 20,
#    'characterColor': 3,
#    'startStocks': 4,
#    'type': 0,
#    'teamId': 0,
#    'controllerFix': 'UCF',
#    'nametag': 'FREE'},
#   {'playerIndex': 3,
#    'port': 4,
#    'characterId': 7,
#    'characterColor': 1,
#    'startStocks': 4,
#    'type': 0,
#    'teamId': 0,
#    'controllerFix': 'UCF',
#    'nametag': ''}]}

# %%
gang.loc[0, 'stats']['stocks']
# Out:
# [{'playerIndex': 0,
#   'opponentIndex': 3,
#   'startFrame': -123,
#   'endFrame': 1399,
#   'startPercent': 0,
#   'endPercent': 10,
#   'currentPercent': 10,
#   'count': 4,
#   'deathAnimation': 0},
#  {'playerIndex': 0,
#   'opponentIndex': 3,
#   'startFrame': 1459,
#   'endFrame': 2695,
#   'startPercent': 0,
#   'endPercent': 60,
#   'currentPercent': 60,
#   'count': 3,
#   'deathAnimation': 0},
#  {'playerIndex': 0,
#   'opponentIndex': 3,
#   'startFrame': 2755,
#   'endFrame': 4781,
#   'startPercent': 0,
#   'endPercent': 42.45000076293945,
#   'currentPercent': 42.45000076293945,
#   'count': 2,
#   'deathAnimation': 0},
#  {'playerIndex': 0,
#   'opponentIndex': 3,
#   'startFrame': 4841,
#   'endFrame': 7183,
#   'startPercent': 0,
#   'endPercent': 82.91999816894531,
#   'currentPercent': 82.91999816894531,
#   'count': 1,
#   'deathAnimation': 0},
#  {'playerIndex': 3,
#   'opponentIndex': 0,
#   'startFrame': -123,
#   'endFrame': 4444,
#   'startPercent': 0,
# ...

# %%
gang.loc[0, 'stats']['conversions']
# Out:
# [{'playerIndex': 0,
#   'opponentIndex': 3,
#   'startFrame': 1572,
#   'endFrame': 1732,
#   'startPercent': 0,
#   'currentPercent': 3,
#   'endPercent': 3,
#   'moves': [{'frame': 1572, 'moveId': 18, 'hitCount': 1}],
#   'didKill': False,
#   'openingType': 'neutral-win'},
#  {'playerIndex': 0,
#   'opponentIndex': 3,
#   'startFrame': 1863,
#   'endFrame': 2070,
#   'startPercent': 3,
#   'currentPercent': 32,
#   'endPercent': 32,
#   'moves': [{'frame': 1863, 'moveId': 21, 'hitCount': 1},
#    {'frame': 1919, 'moveId': 17, 'hitCount': 1},
#    {'frame': 1959, 'moveId': 8, 'hitCount': 1}],
#   'didKill': False,
#   'openingType': 'counter-attack'},
#  {'playerIndex': 0,
#   'opponentIndex': 3,
#   'startFrame': 2115,
#   'endFrame': 2334,
#   'startPercent': 32,
#   'currentPercent': 53.12000274658203,
#   'endPercent': 53.12000274658203,
#   'moves': [{'frame': 2115, 'moveId': 17, 'hitCount': 1},
#    {'frame': 2266, 'moveId': 17, 'hitCount': 1}],
#   'didKill': False,
# ...

# %%
gang.loc[0, 'stats']['lastFrame']
# Out:
# 7183

# %%
gang.loc[0, 'stats']['playableFrameCount']
# Out:
# 7222

# %%
gang.loc[0, 'stats']['overall']
# Out:
# [{'playerIndex': 0,
#   'opponentIndex': 3,
#   'inputCount': 600,
#   'conversionCount': 12,
#   'totalDamage': 283.65999603271484,
#   'killCount': 2,
#   'successfulConversions': {'count': 10,
#    'total': 12,
#    'ratio': 0.833333333333333},
#   'inputsPerMinute': {'count': 600,
#    'total': 2.006111111111111,
#    'ratio': 299.08612572694545},
#   'openingsPerKill': {'count': 12, 'total': 2, 'ratio': 6},
#   'damagePerOpening': {'count': 283.65999603271484,
#    'total': 12,
#    'ratio': 23.638333002726238},
#   'neutralWinRatio': {'count': 9, 'total': 14, 'ratio': 0.642857142857142},
#   'counterHitRatio': {'count': 3, 'total': 10, 'ratio': 0.30000000000000004},
#   'beneficialTradeRatio': {'count': 0, 'total': 0, 'ratio': None}},
#  {'playerIndex': 3,
#   'opponentIndex': 0,
#   'inputCount': 584,
#   'conversionCount': 12,
#   'totalDamage': 195.36999893188477,
#   'killCount': 4,
#   'successfulConversions': {'count': 3, 'total': 12, 'ratio': 0.25},
# ...

# %%
gang.loc[0, 'metadata']
# Out:
# {'startAt': '2019-03-09T08:13:36',
#  'lastFrame': 7183,
#  'consoleNick': 'Station 10',
#  'players': {},
#  'playedOn': 'nintendont'}
